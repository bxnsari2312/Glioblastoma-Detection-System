# %% [markdown]
# # Modeling & Evaluation\nRun training script to fit baseline models and show metrics.

# %%
import os
if not os.path.exists('../data/glioma_grading.csv'):
    os.system('python ../scripts/download_and_preprocess.py')

os.system('python ../scripts/train_model.py')
