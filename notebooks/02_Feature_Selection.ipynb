# %% [markdown]
# # Feature Selection\nRun the script or call functions for filter/wrapper/intrinsic selection.

# %%
import os
if not os.path.exists('../data/glioma_grading.csv'):
    os.system('python ../scripts/download_and_preprocess.py')

os.system('python ../scripts/feature_selection.py')
